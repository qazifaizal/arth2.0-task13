# %%
#Importing packages

import cv2
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
#reading images

img1=cv2.imread('F:\\jupyter\\arth-2.0 tasks\\IMG\\brownlabrador.jpg')
img2=cv2.imread('F:\\jupyter\\arth-2.0 tasks\\IMG\\closeup.jpg')

print(" Image  loaded.")
# Out:
#  Image  loaded.

# %%
img1
# Out:
# array([[[247, 247, 247],
#         [247, 247, 247],
#         [247, 247, 247],
#         ...,
#         [245, 244, 246],
#         [244, 243, 245],
#         [244, 244, 244]],
#
#        [[247, 247, 247],
#         [247, 247, 247],
#         [247, 247, 247],
#         ...,
#         [245, 244, 246],
#         [245, 244, 246],
#         [244, 243, 245]],
#
#        [[247, 247, 247],
#         [247, 247, 247],
#         [247, 247, 247],
#         ...,
#         [245, 244, 246],
#         [245, 244, 246],
#         [245, 244, 246]],
#
#        ...,
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [252, 252, 252],
#         [252, 252, 252],
#         [252, 252, 252]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [252, 252, 252],
#         [252, 252, 252],
#         [252, 252, 252]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
# ...

# %%
img2
# Out:
# array([[[177, 125,  58],
#         [174, 122,  55],
#         [172, 120,  53],
#         ...,
#         [169, 144,  48],
#         [179, 152,  54],
#         [189, 160,  62]],
#
#        [[182, 130,  63],
#         [178, 126,  59],
#         [177, 125,  58],
#         ...,
#         [171, 146,  50],
#         [178, 148,  53],
#         [188, 156,  61]],
#
#        [[190, 139,  69],
#         [188, 137,  67],
#         [188, 137,  67],
#         ...,
#         [171, 146,  50],
#         [179, 145,  52],
#         [189, 152,  60]],
#
#        ...,
#
#        [[ 88,  55,  35],
#         [ 87,  54,  34],
#         [ 87,  55,  36],
#         ...,
#         [223, 138,  82],
#         [227, 140,  84],
#         [229, 144,  88]],
#
#        [[ 89,  56,  36],
#         [ 87,  54,  35],
#         [ 85,  53,  34],
#         ...,
#         [220, 140,  79],
#         [220, 138,  80],
#         [220, 138,  80]],
#
#        [[ 91,  58,  39],
#         [ 89,  56,  37],
#         [ 85,  52,  36],
# ...

# %%
#converting image color to RGB

img1=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)

# %%
img2=cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
img1.shape , img2.shape
# Out:
# ((5027, 3351, 3), (3994, 4002, 3))

# %%
#resizing images

img1=cv2.resize(img1,(450,500))
img1=cv2.resize(img1,(450,500))

# %%
img1.shape , img2.shape
# Out:
# ((500, 450, 3), (3994, 4002, 3))

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
img2_temp=np.copy(img2)

# %%
plt.imshow(img2_temp)

# %%
#cropping part of image1

crop1 = img1[50:180,120:300]
plt.imshow(crop1)

# %%
#adding cropped part of img1 to img2


img2[50:160,120:300]
final_img2=img2

# %%
#cropping part of image2

crop2 = img2_temp[50:180,120:300]
plt.imshow(crop2)

# %%
#adding cropped part of img2 to img1


img1[30:190,120:300]=crop2
final_img1=img1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_136/490103192.py in <module>
#       2
#       3
# ----> 4 img1[30:190,120:300]=crop2
#       5 final_img1=img1
#
# ValueError: could not broadcast input array from shape (130,180,3) into shape (160,180,3)

# %%
plt.imshow(final_img1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_136/157468296.py in <module>
# ----> 1 plt.imshow(final_img1)
#
# NameError: name 'final_img1' is not defined

# %%
#some parts of both the images are swapped

result=np.hstack((final_img1,final_img2))
plt.imshow(result)
